# %% [markdown]
# <a href="https://colab.research.google.com/github/manasakoduri/IT496-A5/blob/main/ManasaK_A5_Risk_Map.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns
import pandas as pd
import numpy as np

riskDF= pd.DataFrame(columns=['risk','likelihood','impact','score'])
riskDF['risk']= ['reputation damage', 'operational downtime', 'users','financial loss']
riskDF['likelihood']=[0.2,0.4,0.6,0.8]
riskDF['impact']=[2,4,6,8]
riskDF['score']=riskDF['impact']*riskDF['likelihood']

scoresPivot=riskDF.pivot('impact','likelihood','score')

labelsPivot=riskDF.pivot('impact','likelihood','risk')

sns.set(rc={'figure.figsize':(8,8)})
p1=sns.heatmap(scoresPivot, cmap='hot_r', annot=labelsPivot, fmt='')
